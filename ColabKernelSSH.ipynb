# %% [markdown]
# Based on code from:
#
# https://pypi.org/project/colab-ssh/
#
# this one details how to make extensions permanent, but it's a different method of running the server. In experimentation, the extensions didnn't 100% work either
#
# https://towardsdatascience.com/colab-free-gpu-ssh-visual-studio-code-server-36fe1d3c5243

# %% [markdown]
# # Instructions
# ### Step 1
# Make sure that you set the run time to GPU
#
# Sign up to ngrok here: https://dashboard.ngrok.com/
#
# Run the below code
#
#
# ngrokToken: input the token you get from here https://dashboard.ngrok.com/auth/your-authtoken\
#
# password: password you will use to SSH from VS code
#
# ### Step 2
# Note down the output of launch_ssh(). Specifically:
#
# ![image.png](data:image/png;base64,...)
#
# DO NOT CLOSE COLAB. Basically, you are sshing into the Kernel that this page is keeping open. For as long as you are working on it in VS Code, do NOT close this page.
#
# ### Step 3
# Open VS code, install these packages
#
# ![image.png](data:image/png;base64,...)
#
# ### Step 4
# Click on this icon and set the remote exploer to SSH:
#
# ![image.png](data:image/png;base64,...)
#
# ### Step 5
# Click on the little gear icon in SSH Targets for settings, select the first option (Should be some path to a config file). Go into that file, and then copy and paste the output you saved from step 2
#
# ![image.png](data:image/png;base64,...)
#
# Note, you will have to update this file with the proper parameters everytime you restart the Colab Note book (By factory resetting the kernel or crashing the kernel or simply closing the webpage)
#
# ### Step 6
# Under SSH Targets that you saw in step 4, you should now see google_colab_ssh. Right click on this file, then connect to host. This should reload your VS code, and then ask you for passwords and stuff that u set up in step 1.
#
# ### Step 7
# Every time you restart your kernel, you are going to have to install these packages to this instance of the server. Maybe there's a way around this, I could not find it if so. But it shouldn't take long anyway.
#
# ![image.png](data:image/png;base64,...)\
# ![image.png](data:image/png;base64,...)
#
# Feel free to find out if there is a way to make this permanant, i coudln't find it
#
# ### Step i've forgotten
# From this point there isn't much you have to do. you can click on the
#
# ![image.png](data:image/png;base64,...)\
# Icon and clone the git directly. This would mean however, that you'd need to clone the repo every time you start. I'd suggest instead, that you optionally link up the google drive, and using the clone repo function in VS code, save the repo to your google drive. This would mean that next time, you'd just need to open up VS code remotely, and download the extensions to the remote version, and just open the repo instead of having to download it.
#
# ### Additional Notes
# When you open up a .ipynb file, it will take VS Code a min to realise it's jupyter and load it like a jupyter file
#
# When you do open up jupyter file, make sure you are using the google drive's kernel. For me, almost always it default to the one i had on my computer.\
# ![image.png](data:image/png;base64,...)\
# You can click on this on the top right of the window to change the kernel

# %% [markdown]
# # IMPORTANT
# When working on VS Code, make sure u keep saving, and before you commit, make sure all changes have been detected by git. It's a bit slow on this.

# %%
# !nvcc --version

# %%
# !pip uninstall torch torchvision
# !pip install torch==1.5.0+cu101 torchvision==0.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())

# %%
# !pip install colab_ssh --upgrade
from colab_ssh import launch_ssh, init_git

# %%
ngrokToken = '' #Enter Your ngrok Token here
password   = '' #Enter the password you will give to your kernel here
launch_ssh(ngrokToken,password)
# Out:
# Successfully running 0.tcp.ngrok.io:16289
# [Optional] You can also connect with VSCode SSH Remote extension using this configuration:
#
# 	Host google_colab_ssh
# 		HostName 0.tcp.ngrok.io
# 		User root
# 		Port 16289

# %%
#Optional
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
""" Copy and paste into colab webpage inspector to make sure colab dosen't time out
function ConnectButton(){
    console.log("Connect pushed"); 
    document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click() 
}
setInterval(ConnectButton,60000);
"""
